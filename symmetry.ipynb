# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifParser
from pymatgen.io.cif import CifWriter
from pymatgen import Lattice, Structure
from pymatgen.entries.compatibility import MaterialsProjectCompatibility
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from pymatgen.core.operations import SymmOp
from IPython.display import Image
from jupyter_jsmol.pymatgen import quick_view

# %%
xtal = Structure.from_file("LiHF2_mp-24199_symmetrized.cif")

# %%
summary=SpacegroupAnalyzer(xtal).get_primitive_standard_structure()
print(summary)
print(summary.sites)
positions=summary.sites
# Out:
# Full Formula (Li1 H1 F2)
# Reduced Formula: LiHF2
# abc   :   4.772357   4.772357   4.772357
# angles:  37.065004  37.065004  37.065004
# Sites (4)
#   #  SP           a         b         c
# ---  ----  --------  --------  --------
#   0  Li    0         0         0
#   1  H     0.5       0.5       0.5
#   2  F     0.413848  0.413848  0.413848
#   3  F     0.586152  0.586152  0.586152
# [PeriodicSite: Li (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000], PeriodicSite: H (6.5331, 0.0000, 1.2888) [0.5000, 0.5000, 0.5000], PeriodicSite: F (5.4074, 0.0000, 1.0667) [0.4138, 0.4138, 0.4138], PeriodicSite: F (7.6587, -0.0000, 1.5109) [0.5862, 0.5862, 0.5862]]

# %%
symétrie1=SymmOp.from_xyz_string("x,y,z")
from IPython.display import Image
print("LiHF2 : sans transformation")
Image(filename='sans_transformation.JPG')
# Out:
# LiHF2 : sans transformation

# %%
symétrie2=SymmOp.from_xyz_string("-x,-y,-z") #on a pris la symmétrie 2 à l'atome 7
from IPython.display import Image
print("LiHF2 : inversion")
Image(filename='inversion.JPG')
# Out:
# LiHF2 : inversion

# %%
symétrie24=SymmOp.from_xyz_string("x+2/3, x-y+1/3, z+1/3") #glissement à l'atome 6
from IPython.display import Image
print("LiHF2 : glissement")
Image(filename='glissement.JPG')
# Out:
# LiHF2 : glissement

# %%
symétrie17=SymmOp.from_xyz_string("-x+y+2/3, -x+1/3, z+1/3") #3_bar_axe (roto-inversion) en atome 5
from IPython.display import Image
print("LiHF2 : 3_bar_axe")
Image(filename='3_bar_axis.JPG')
# Out:
# LiHF2 : 3_bar_axe
